# %%
import pandas as pd

# %%
a=[1,2,3,4,5]

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
b=pd.Series(a)

# %%
b
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
dir(b)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
c=(1,5,8,7,10)

# %%
d=pd.Series(c)

# %%
e={"name":"rinsiya","name2":"nisfa","name3":"majida"}

# %%
f=pd.Series(e)

# %%
f
# Out:
# name     rinsiya
# name2      nisfa
# name3     majida
# dtype: object

# %%
import numpy as np

# %%
g=np.array([1,2,3,4])

# %%
h=pd.Series(g)

# %%
h
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(100)
a1=np.random.randn(7,8)

# %%
a1
# Out:
# array([[-1.74976547,  0.3426804 ,  1.1530358 , -0.25243604,  0.98132079,
#          0.51421884,  0.22117967, -1.07004333],
#        [-0.18949583,  0.25500144, -0.45802699,  0.43516349, -0.58359505,
#          0.81684707,  0.67272081, -0.10441114],
#        [-0.53128038,  1.02973269, -0.43813562, -1.11831825,  1.61898166,
#          1.54160517, -0.25187914, -0.84243574],
#        [ 0.18451869,  0.9370822 ,  0.73100034,  1.36155613, -0.32623806,
#          0.05567601,  0.22239961, -1.443217  ],
#        [-0.75635231,  0.81645401,  0.75044476, -0.45594693,  1.18962227,
#         -1.69061683, -1.35639905, -1.23243451],
#        [-0.54443916, -0.66817174,  0.00731456, -0.61293874,  1.29974807,
#         -1.73309562, -0.9833101 ,  0.35750775],
#        [-1.6135785 ,  1.47071387, -1.1880176 , -0.54974619, -0.94004616,
#         -0.82793236,  0.10886347,  0.50780959]])

# %%
df=pd.DataFrame(a1,index=['a','b','c','d','e','f','g'],columns=['h','i','j','k','l','m','n','o'])

# %%
df
# Out:
#           h         i         j         k         l         m         n  \
# a -1.749765  0.342680  1.153036 -0.252436  0.981321  0.514219  0.221180
# b -0.189496  0.255001 -0.458027  0.435163 -0.583595  0.816847  0.672721
# c -0.531280  1.029733 -0.438136 -1.118318  1.618982  1.541605 -0.251879
# d  0.184519  0.937082  0.731000  1.361556 -0.326238  0.055676  0.222400
# e -0.756352  0.816454  0.750445 -0.455947  1.189622 -1.690617 -1.356399
# f -0.544439 -0.668172  0.007315 -0.612939  1.299748 -1.733096 -0.983310
# g -1.613579  1.470714 -1.188018 -0.549746 -0.940046 -0.827932  0.108863
#
#           o
# a -1.070043
# b -0.104411
# c -0.842436
# d -1.443217
# e -1.232435
# f  0.357508
# g  0.507810

# %%
df1=pd.DataFrame(a1)

# %%
df1
# Out:
#           0         1         2         3         4         5         6  \
# 0 -1.749765  0.342680  1.153036 -0.252436  0.981321  0.514219  0.221180
# 1 -0.189496  0.255001 -0.458027  0.435163 -0.583595  0.816847  0.672721
# 2 -0.531280  1.029733 -0.438136 -1.118318  1.618982  1.541605 -0.251879
# 3  0.184519  0.937082  0.731000  1.361556 -0.326238  0.055676  0.222400
# 4 -0.756352  0.816454  0.750445 -0.455947  1.189622 -1.690617 -1.356399
# 5 -0.544439 -0.668172  0.007315 -0.612939  1.299748 -1.733096 -0.983310
# 6 -1.613579  1.470714 -1.188018 -0.549746 -0.940046 -0.827932  0.108863
#
#           7
# 0 -1.070043
# 1 -0.104411
# 2 -0.842436
# 3 -1.443217
# 4 -1.232435
# 5  0.357508
# 6  0.507810
